# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_03.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dicionario = {"Nome": ["Pedro", "Ana", "Karina", "Patricia", "Carlos", "Felipe", "Jose", "Gustavo", "Fernando"],
                 "Idade": [20,21,19,18,23,21,27,30,22]
                 }

# %%
df = pd.DataFrame(dicionario)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro     20
# 1       Ana     21
# 2    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.rename(index={0:"x", 1:"y", 2: "z"}, inplace=True)

# %%
df.head()
# Out:
#        Nome  Idade
# x     Pedro     20
# y       Ana     21
# z    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro     20
# 1       Ana     21
# 2    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.dtypes
# Out:
# Nome     object
# Idade     int64
# dtype: object

# %%
df["Idade"] = df["Idade"].astype(float)
#alterar tipo de dado

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro   20.0
# 1       Ana   21.0
# 2    Karina   19.0
# 3  Patricia   18.0
# 4    Carlos   23.0

# %%
df.dtypes
# Out:
# Nome      object
# Idade    float64
# dtype: object

# %%
df["Idade"].value_counts()
# Out:
# 21.0    2
# 20.0    1
# 19.0    1
# 18.0    1
# 23.0    1
# 27.0    1
# 30.0    1
# 22.0    1
# Name: Idade, dtype: int64

# %%
df.assign(Nova_Idade=df["Idade"]*2)
#mostra como fica, não altera
# Out:
#        Nome  Idade  Nova_Idade
# 0     Pedro   20.0        40.0
# 1       Ana   21.0        42.0
# 2    Karina   19.0        38.0
# 3  Patricia   18.0        36.0
# 4    Carlos   23.0        46.0
# 5    Felipe   21.0        42.0
# 6      Jose   27.0        54.0
# 7   Gustavo   30.0        60.0
# 8  Fernando   22.0        44.0

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro   20.0
# 1       Ana   21.0
# 2    Karina   19.0
# 3  Patricia   18.0
# 4    Carlos   23.0

# %%
df = df.assign(Nova_Idade=df["Idade"]*2)

# %%
df.head()
# Out:
#        Nome  Idade  Nova_Idade
# 0     Pedro   20.0        40.0
# 1       Ana   21.0        42.0
# 2    Karina   19.0        38.0
# 3  Patricia   18.0        36.0
# 4    Carlos   23.0        46.0

# %%
df["x"] = df["Nova_Idade"] - 20

# %%
df.head()
# Out:
#        Nome  Idade  Nova_Idade     x
# 0     Pedro   20.0        40.0  20.0
# 1       Ana   21.0        42.0  22.0
# 2    Karina   19.0        38.0  18.0
# 3  Patricia   18.0        36.0  16.0
# 4    Carlos   23.0        46.0  26.0

# %%
df.select_dtypes(include="number")
# Out:
#    Idade  Nova_Idade     x
# 0   20.0        40.0  20.0
# 1   21.0        42.0  22.0
# 2   19.0        38.0  18.0
# 3   18.0        36.0  16.0
# 4   23.0        46.0  26.0
# 5   21.0        42.0  22.0
# 6   27.0        54.0  34.0
# 7   30.0        60.0  40.0
# 8   22.0        44.0  24.0

# %%
df.select_dtypes(include="object")
# Out:
#        Nome
# 0     Pedro
# 1       Ana
# 2    Karina
# 3  Patricia
# 4    Carlos
# 5    Felipe
# 6      Jose
# 7   Gustavo
# 8  Fernando

# %%
df.select_dtypes(include="number").columns
# Out:
# Index(['Idade', 'Nova_Idade', 'x'], dtype='object')

# %%
df.drop(["Nova_Idade", "x"], inplace=True, axis=1)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro   20.0
# 1       Ana   21.0
# 2    Karina   19.0
# 3  Patricia   18.0
# 4    Carlos   23.0

# %%
df.drop([2,3], inplace=True, axis=0)

# %%
df.head()
# Out:
#      Nome  Idade
# 0   Pedro   20.0
# 1     Ana   21.0
# 4  Carlos   23.0
# 5  Felipe   21.0
# 6    Jose   27.0

# %%
df.reset_index(inplace=True, drop=True)

# %%
df.head()
# Out:
#      Nome  Idade
# 0   Pedro   20.0
# 1     Ana   21.0
# 2  Carlos   23.0
# 3  Felipe   21.0
# 4    Jose   27.0
