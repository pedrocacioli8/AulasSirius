# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_04_Importar_e_Exportar_arquivos_com_Pandas.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("ideb (1).csv")

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.shape
# Out:
# (200226, 13)

# %%
df.dtypes
# Out:
# ano                              int64
# sigla_uf                        object
# id_municipio                     int64
# rede                            object
# ensino                          object
# anos_escolares                  object
# taxa_aprovacao                 float64
# indicador_rendimento           float64
# nota_saeb_matematica           float64
# nota_saeb_lingua_portuguesa    float64
# nota_saeb_media_padronizada    float64
# ideb                           float64
# projecao                       float64
# dtype: object

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 200226 entries, 0 to 200225
# Data columns (total 13 columns):
#  #   Column                       Non-Null Count   Dtype
# ---  ------                       --------------   -----
#  0   ano                          200226 non-null  int64
#  1   sigla_uf                     200226 non-null  object
#  2   id_municipio                 200226 non-null  int64
#  3   rede                         200226 non-null  object
#  4   ensino                       200226 non-null  object
#  5   anos_escolares               200226 non-null  object
#  6   taxa_aprovacao               136633 non-null  float64
#  7   indicador_rendimento         136623 non-null  float64
#  8   nota_saeb_matematica         114611 non-null  float64
#  9   nota_saeb_lingua_portuguesa  114611 non-null  float64
#  10  nota_saeb_media_padronizada  127877 non-null  float64
#  11  ideb                         127844 non-null  float64
# ...

# %%
df["rede"].value_counts()
# Out:
# publica      75986
# estadual     66181
# municipal    56684
# federal       1375
# Name: rede, dtype: int64

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Arquivos/ideb (1).csv")

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
df["x"] = df["ano"]*2

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao  \
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
df[["ano", "rede", "x"]]
# Out:
#          ano       rede     x
# 0       2005  municipal  4010
# 1       2005   estadual  4010
# 2       2005  municipal  4010
# 3       2005    publica  4010
# 4       2005  municipal  4010
# ...      ...        ...   ...
# 294421  2019    publica  4038
# 294422  2019  municipal  4038
# 294423  2019  municipal  4038
# 294424  2019    publica  4038
# 294425  2019   estadual  4038
#
# [294426 rows x 3 columns]

# %%
#exportar para uma pasta
df.to_csv("/content/drive/MyDrive/Arquivos/meu_arquivo.csv", index=False)

# %%
df = pd.read_csv("/content/drive/MyDrive/Arquivos/meu_arquivo.csv")

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao  \
# 0                       165.60                     4.177761   2.3       NaN
# ...
