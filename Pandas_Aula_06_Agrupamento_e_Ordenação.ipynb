# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_06_Agrupamento_e_Ordena%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Arquivos/ideb (1).csv")

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
df_new = df.loc[:,["sigla_uf", "rede", "ensino", "ideb"]]

# %%
df_new.head()
# Out:
#   sigla_uf       rede       ensino  ideb
# 0       AC  municipal  fundamental   2.3
# 1       AC   estadual  fundamental   1.8
# 2       AC  municipal  fundamental   1.9
# 3       AC    publica  fundamental   1.9
# 4       AC  municipal  fundamental   2.3

# %%
df.groupby(["rede"])["ideb"].mean()
# Out:
# rede
# estadual     4.239154
# federal      5.729919
# municipal    4.402423
# publica      4.344527
# Name: ideb, dtype: float64

# %%
df.groupby(["rede", "ensino"])["ideb"].sum()
# Out:
# rede       ensino
# estadual   fundamental    223557.6
#            medio           37866.8
# federal    fundamental      1251.6
#            medio            2272.3
# municipal  fundamental    282185.7
#            medio             559.9
# publica    fundamental    376975.4
#            medio           38083.3
# Name: ideb, dtype: float64

# %%
df.groupby(["rede", "ensino"])[["ideb"]].sum()
# Out:
#                            ideb
# rede      ensino
# estadual  fundamental  223557.6
#           medio         37866.8
# federal   fundamental    1251.6
#           medio          2272.3
# municipal fundamental  282185.7
#           medio           559.9
# publica   fundamental  376975.4
#           medio         38083.3

# %%
df["rede"].value_counts()
# Out:
# publica      116823
# estadual      92058
# municipal     83898
# federal        1647
# Name: rede, dtype: int64

# %%
df["ensino"].value_counts()
# Out:
# fundamental    259551
# medio           34875
# Name: ensino, dtype: int64

# %%
df_new.head()
# Out:
#   sigla_uf       rede       ensino  ideb
# 0       AC  municipal  fundamental   2.3
# 1       AC   estadual  fundamental   1.8
# 2       AC  municipal  fundamental   1.9
# 3       AC    publica  fundamental   1.9
# 4       AC  municipal  fundamental   2.3

# %%
df_new.sort_values(["ideb"], ascending=True, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 2674       PA   estadual  fundamental   0.1
# 4514       BA   estadual  fundamental   0.3
# 644        BA  municipal  fundamental   0.3
# 646        BA    publica  fundamental   0.3
# 2630       PA   estadual  fundamental   0.5

# %%
df_new.sort_values(["ideb"], ascending=False, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 9062       CE  municipal  fundamental   9.4
# 9064       CE    publica  fundamental   9.4
# 6764       CE    publica  fundamental   9.1
# 9036       CE  municipal  fundamental   9.1
# 9037       CE    publica  fundamental   9.1

# %%
df_new.sort_values(["ideb", "rede"], ascending=False, inplace=True)

# %%
df_new.head()
# Out:
#      sigla_uf       rede       ensino  ideb
# 9064       CE    publica  fundamental   9.4
# 9062       CE  municipal  fundamental   9.4
# 6764       CE    publica  fundamental   9.1
# 9037       CE    publica  fundamental   9.1
# 9036       CE  municipal  fundamental   9.1
