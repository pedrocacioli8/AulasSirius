# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_08_Substituindo_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dicionario = {"Nome": ["Pedro", "Ana", "Karina", "Patricia", "Carlos", "Felipe", "Jose", "Gustavo", "Fernando"],
                 "Idade": [20,21,19,18,23,21,27,30,22]
                 }

# %%
df = pd.DataFrame(dicionario)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro     20
# 1       Ana     21
# 2    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.replace(21, 100, inplace=True)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro     20
# 1       Ana    100
# 2    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.replace([20, 19, 18], 4, inplace=True)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro      4
# 1       Ana    100
# 2    Karina      4
# 3  Patricia      4
# 4    Carlos     23

# %%
df["Nome"] = df["Nome"].replace("Pedro", "Larissa")

# %%
df.head()
# Out:
#        Nome  Idade
# 0   Larissa      4
# 1       Ana    100
# 2    Karina      4
# 3  Patricia      4
# 4    Carlos     23

# %%
df["Nome"].replace("Karina", "Daniel", inplace=True)

# %%
df.head()
# Out:
#        Nome  Idade
# 0   Larissa      4
# 1       Ana    100
# 2    Daniel      4
# 3  Patricia      4
# 4    Carlos     23

# %%
df["Nome"].replace({"Patricia":"Ana", "Carlos": "Felipe"}, inplace=True)

# %%
df.head()
# Out:
#       Nome  Idade
# 0  Larissa      4
# 1      Ana    100
# 2   Daniel      4
# 3      Aba      4
# 4   Felipe     23
