# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/S1D3_Correla%C3%A7%C3%A3o.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_excel("Fonte dos Dados (1).xlsx")

# %%
df.head()
# Out:
#   nomeLocalidade estado  População residente  Densidade demográfica  \
# 0     Acrelândia   Acre                12538                   6.93
# 1   Assis Brasil   Acre                 6072                   1.22
# 2      Brasiléia   Acre                21398                   5.46
# 3         Bujari   Acre                 8471                   2.79
# 4       Capixaba   Acre                 8798                   5.17
#
#    Porcentagem de Jovens  Porcentagem de Ativos  Porcentagem de Idosos  \
# 0                  52.92                  43.04                   4.04
# 1                  55.58                  40.07                   4.35
# 2                  51.88                  42.76                   5.37
# 3                  52.71                  42.60                   4.69
# 4                  53.92                  41.92                   4.16
#
#    Taxa de Urbanização  Taxa de Saneamento Básico  \
# 0                48.34                       0.00
# ...

# %%
df.corr()
# Out:
# <ipython-input-5-2f6f6606aa2c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   df.corr()
#                                                     População residente  \
# População residente                                            1.000000
# Densidade demográfica                                          0.440335
# Porcentagem de Jovens                                         -0.030194
# Porcentagem de Ativos                                          0.074956
# Porcentagem de Idosos                                         -0.072246
# Taxa de Urbanização                                            0.157333
# Taxa de Saneamento Básico                                      0.126659
# Ativos com Baixo Nível Educacional                            -0.245494
# ...

# %%
import seaborn as sns

# %%
sns.scatterplot(data=df, x="Taxa de Urbanização", y= "Taxa de Saneamento Básico");

# %%
df[["Taxa de Urbanização", "Taxa de Saneamento Básico"]].corr()
# Out:
#                            Taxa de Urbanização  Taxa de Saneamento Básico
# Taxa de Urbanização                   1.000000                   0.550341
# Taxa de Saneamento Básico             0.550341                   1.000000

# %%
df[["Taxa de Urbanização", "Taxa de Saneamento Básico"]].corr(method="pearson")
# Out:
#                            Taxa de Urbanização  Taxa de Saneamento Básico
# Taxa de Urbanização                   1.000000                   0.550341
# Taxa de Saneamento Básico             0.550341                   1.000000

# %%
df[["Taxa de Urbanização", "Taxa de Saneamento Básico"]].corr(method="spearman")
# Out:
#                            Taxa de Urbanização  Taxa de Saneamento Básico
# Taxa de Urbanização                    1.00000                    0.54749
# Taxa de Saneamento Básico              0.54749                    1.00000

# %%
df[["Taxa de Urbanização", "Taxa de Saneamento Básico"]].corr(method="kendall")
# Out:
#                            Taxa de Urbanização  Taxa de Saneamento Básico
# Taxa de Urbanização                   1.000000                   0.389793
# Taxa de Saneamento Básico             0.389793                   1.000000

# %%
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True);
# Out:
# <ipython-input-15-d29a23d1181c>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=True);

# %%
sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=False);
# Out:
# <ipython-input-16-2565522d9d25>:1: FutureWarning: The default value of numeric_only in DataFrame.corr is deprecated. In a future version, it will default to False. Select only valid columns or specify the value of numeric_only to silence this warning.
#   sns.heatmap(df.corr(), vmin=-1, vmax=1, annot=False);
