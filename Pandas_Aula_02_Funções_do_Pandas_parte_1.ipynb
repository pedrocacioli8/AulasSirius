# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_02_Fun%C3%A7%C3%B5es_do_Pandas_parte_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
dicionario = {"Nome": ["Pedro", "Ana", "Karina", "Patricia", "Carlos", "Felipe", "Jose", "Gustavo", "Fernando"],
                 "Idade": [20,21,19,18,23,21,27,30,22]
                 }

# %%
df = pd.DataFrame(dicionario)

# %%
df.head()
# Out:
#        Nome  Idade
# 0     Pedro     20
# 1       Ana     21
# 2    Karina     19
# 3  Patricia     18
# 4    Carlos     23

# %%
df.columns
# Out:
# Index(['Nome', 'Idade'], dtype='object')

# %%
df.rename(columns={"Nome":"Nome Completo"}, inplace=True)

# %%
df.head()
# Out:
#   Nome Completo  Idade
# 0         Pedro     20
# 1           Ana     21
# 2        Karina     19
# 3      Patricia     18
# 4        Carlos     23

# %%
df.rename(index={0: "x", 1: "y", 2: "z"}, inplace = True)

# %%
df.head()
# Out:
#   Nome Completo  Idade
# x         Pedro     20
# y           Ana     21
# z        Karina     19
# 3      Patricia     18
# 4        Carlos     23

# %%
df.rename(str.lower, axis="columns", inplace=True)
#colocar tudo em minúsculo

# %%
df.head()
# Out:
#   nome completo  idade
# x         Pedro     20
# y           Ana     21
# z        Karina     19
# 3      Patricia     18
# 4        Carlos     23

# %%
df.index
# Out:
# Index(['x', 'y', 'z', 3, 4, 5, 6, 7, 8], dtype='object')

# %%
df.dtypes
# Out:
# nome completo    object
# idade             int64
# dtype: object

# %%
df.shape
# Out:
# (9, 2)

# %%
df.info()
#resumo do data frame
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9 entries, x to 8
# Data columns (total 2 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   nome completo  9 non-null      object
#  1   idade          9 non-null      int64
# dtypes: int64(1), object(1)
# memory usage: 516.0+ bytes

# %%
df.values
# Out:
# array([['Pedro', 20],
#        ['Ana', 21],
#        ['Karina', 19],
#        ['Patricia', 18],
#        ['Carlos', 23],
#        ['Felipe', 21],
#        ['Jose', 27],
#        ['Gustavo', 30],
#        ['Fernando', 22]], dtype=object)
