# %% [markdown]
# <a href="https://colab.research.google.com/github/pedrocacioli8/AulasSirius/blob/main/Pandas_Aula_05_Indexa%C3%A7%C3%A3o_e_Sele%C3%A7%C3%A3o_de_Dados.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive

# %%
drive.mount("/content/drive")
# Out:
# Mounted at /content/drive

# %%
df = pd.read_csv("/content/drive/MyDrive/Arquivos/ideb (1).csv")

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
df["rede"]
# Out:
# 0         municipal
# 1          estadual
# 2         municipal
# 3           publica
# 4         municipal
#             ...
# 294421      publica
# 294422    municipal
# 294423    municipal
# 294424      publica
# 294425     estadual
# Name: rede, Length: 294426, dtype: object

# %%
df[["rede"]]
# Out:
#              rede
# 0       municipal
# 1        estadual
# 2       municipal
# 3         publica
# 4       municipal
# ...           ...
# 294421    publica
# 294422  municipal
# 294423  municipal
# 294424    publica
# 294425   estadual
#
# [294426 rows x 1 columns]

# %%
df[["ano", "rede"]]
# Out:
#          ano       rede
# 0       2005  municipal
# 1       2005   estadual
# 2       2005  municipal
# 3       2005    publica
# 4       2005  municipal
# ...      ...        ...
# 294421  2019    publica
# 294422  2019  municipal
# 294423  2019  municipal
# 294424  2019    publica
# 294425  2019   estadual
#
# [294426 rows x 2 columns]

# %%
df["rede"][1]
# Out:
# 'estadual'

# %%
df["rede"][2:5]
# Out:
# 2    municipal
# 3      publica
# 4    municipal
# Name: rede, dtype: object

# %%
df[["rede"]][2:5]
# Out:
#         rede
# 2  municipal
# 3    publica
# 4  municipal

# %%
df.loc[:, :]
# Out:
#          ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0       2005       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1       2005       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2       2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3       2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4       2005       AC       1200336  municipal  fundamental  iniciais (1-5)
# ...      ...      ...           ...        ...          ...             ...
# 294421  2019       SP       3551108    publica  fundamental  iniciais (1-5)
# 294422  2019       SP       3551702  municipal  fundamental    finais (6-9)
# 294423  2019       SP       3555406  municipal  fundamental  iniciais (1-5)
# 294424  2019       SP       3555406    publica  fundamental  iniciais (1-5)
# 294425  2019       TO       1716653   estadual  fundamental  iniciais (1-5)
#
# ...

# %%
df.loc[:,["ano"]]
# Out:
#          ano
# 0       2005
# 1       2005
# 2       2005
# 3       2005
# 4       2005
# ...      ...
# 294421  2019
# 294422  2019
# 294423  2019
# 294424  2019
# 294425  2019
#
# [294426 rows x 1 columns]

# %%
df.loc[:,["ano", "rede"]]
# Out:
#          ano       rede
# 0       2005  municipal
# 1       2005   estadual
# 2       2005  municipal
# 3       2005    publica
# 4       2005  municipal
# ...      ...        ...
# 294421  2019    publica
# 294422  2019  municipal
# 294423  2019  municipal
# 294424  2019    publica
# 294425  2019   estadual
#
# [294426 rows x 2 columns]

# %%
df.loc[5, ["ano", "rede"]]
# Out:
# ano         2005
# rede    estadual
# Name: 5, dtype: object

# %%
df.loc[2:5]
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
# 5  2005       AC       1200344   estadual  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
# 5            58.6              0.621268                 156.6
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2                       155.80                     3.920963   1.9       NaN
# 3                       153.39                     3.785995   1.9       NaN
# ...

# %%
df.loc[2:5, :]
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2005       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2005       AC       1200336  municipal  fundamental  iniciais (1-5)
# 5  2005       AC       1200344   estadual  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
# 5            58.6              0.621268                 156.6
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2                       155.80                     3.920963   1.9       NaN
# 3                       153.39                     3.785995   1.9       NaN
# ...

# %%
df.loc[[2]]
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 2  2005       AC       1200328  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 2            48.8              0.494267                 163.6
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 2                        155.8                     3.920963   1.9       NaN

# %%
df.loc[2:5, ["ano", "rede"]]
# Out:
#     ano       rede
# 2  2005  municipal
# 3  2005    publica
# 4  2005  municipal
# 5  2005   estadual

# %%
df.loc[df["ano"] == 2011]
# Out:
#          ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 3809    2011       AL       2700102   estadual  fundamental    finais (6-9)
# 3810    2011       AL       2700201  municipal  fundamental    finais (6-9)
# 3811    2011       AL       2700409   estadual  fundamental    finais (6-9)
# 3812    2011       AL       2700607  municipal  fundamental    finais (6-9)
# 3813    2011       AL       2700607    publica  fundamental    finais (6-9)
# ...      ...      ...           ...        ...          ...             ...
# 292489  2011       SP       3550803    publica  fundamental  iniciais (1-5)
# 292490  2011       SP       3554409  municipal  fundamental  iniciais (1-5)
# 292491  2011       SP       3554409    publica  fundamental  iniciais (1-5)
# 292492  2011       SP       3556107  municipal  fundamental  iniciais (1-5)
# 292493  2011       SP       3556107    publica  fundamental  iniciais (1-5)
#
# ...

# %%
#condição E
df.loc[(df["ano"]==2011) & (df["rede"]=="publica")]
# Out:
#          ano sigla_uf  id_municipio     rede       ensino  anos_escolares  \
# 3813    2011       AL       2700607  publica  fundamental    finais (6-9)
# 3815    2011       AL       2701001  publica  fundamental    finais (6-9)
# 3817    2011       AL       2701100  publica  fundamental    finais (6-9)
# 3819    2011       AL       2701209  publica  fundamental    finais (6-9)
# 3821    2011       AL       2701308  publica  fundamental    finais (6-9)
# ...      ...      ...           ...      ...          ...             ...
# 292484  2011       SP       3544707  publica  fundamental  iniciais (1-5)
# 292486  2011       SP       3547908  publica  fundamental  iniciais (1-5)
# 292489  2011       SP       3550803  publica  fundamental  iniciais (1-5)
# 292491  2011       SP       3554409  publica  fundamental  iniciais (1-5)
# 292493  2011       SP       3556107  publica  fundamental  iniciais (1-5)
#
#         taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# ...

# %%
#condição OU
df.loc[(df["ano"]==2011) | (df["rede"]=="publica")]
# Out:
#          ano sigla_uf  id_municipio     rede       ensino  anos_escolares  \
# 3       2005       AC       1200328  publica  fundamental  iniciais (1-5)
# 7       2005       AC       1200344  publica  fundamental  iniciais (1-5)
# 9       2005       AC       1200351  publica  fundamental  iniciais (1-5)
# 11      2005       AC       1200393  publica  fundamental  iniciais (1-5)
# 13      2005       AC       1200435  publica  fundamental  iniciais (1-5)
# ...      ...      ...           ...      ...          ...             ...
# 294414  2019       SP       3545506  publica  fundamental  iniciais (1-5)
# 294416  2019       SP       3548807  publica  fundamental    finais (6-9)
# 294418  2019       SP       3549201  publica  fundamental  iniciais (1-5)
# 294421  2019       SP       3551108  publica  fundamental  iniciais (1-5)
# 294424  2019       SP       3555406  publica  fundamental  iniciais (1-5)
#
#         taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# ...

# %%
#substituição
df.loc[0:5, ["ano"]] = 2022

# %%
df.head()
# Out:
#     ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0  2022       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1  2022       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2  2022       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3  2022       AC       1200328    publica  fundamental  iniciais (1-5)
# 4  2022       AC       1200336  municipal  fundamental  iniciais (1-5)
#
#    taxa_aprovacao  indicador_rendimento  nota_saeb_matematica  \
# 0            53.9              0.561795                 167.8
# 1            49.3              0.501470                 151.8
# 2            48.8              0.494267                 163.6
# 3            48.8              0.497858                 159.0
# 4            74.7              0.752579                 138.0
#
#    nota_saeb_lingua_portuguesa  nota_saeb_media_padronizada  ideb  projecao
# 0                       165.60                     4.177761   2.3       NaN
# ...

# %%
df.iloc[:,:]
# Out:
#          ano sigla_uf  id_municipio       rede       ensino  anos_escolares  \
# 0       2022       AC       1200302  municipal  fundamental  iniciais (1-5)
# 1       2022       AC       1200328   estadual  fundamental  iniciais (1-5)
# 2       2022       AC       1200328  municipal  fundamental  iniciais (1-5)
# 3       2022       AC       1200328    publica  fundamental  iniciais (1-5)
# 4       2022       AC       1200336  municipal  fundamental  iniciais (1-5)
# ...      ...      ...           ...        ...          ...             ...
# 294421  2019       SP       3551108    publica  fundamental  iniciais (1-5)
# 294422  2019       SP       3551702  municipal  fundamental    finais (6-9)
# 294423  2019       SP       3555406  municipal  fundamental  iniciais (1-5)
# 294424  2019       SP       3555406    publica  fundamental  iniciais (1-5)
# 294425  2019       TO       1716653   estadual  fundamental  iniciais (1-5)
#
# ...

# %%
df.iloc[0:5, 0]
# Out:
# 0    2022
# 1    2022
# 2    2022
# 3    2022
# 4    2022
# Name: ano, dtype: int64
